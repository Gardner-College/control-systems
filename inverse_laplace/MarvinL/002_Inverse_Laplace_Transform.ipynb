# %% [markdown]
# - **Name: Marvin D. Llames**
# - **Term: 2nd year 3rd term**

# %% [markdown]
# ##### Required Python Packages
# Run the following applications once if they are not yet installed in your Python environment:

# %%
# !pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.3.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Downloading numpy-2.3.1-cp313-cp313-win_amd64.whl (12.7 MB)
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ---------------------------------------  12.6/12.7 MB 117.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.7/12.7 MB 50.2 MB/s eta 0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.3.1

# %%
# !pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.16.0-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\miranda family\new folder\envs\control-system\lib\site-packages (from scipy) (2.3.1)
# Downloading scipy-1.16.0-cp313-cp313-win_amd64.whl (38.4 MB)
#    ---------------------------------------- 0.0/38.4 MB ? eta -:--:--
#    ------------------------- -------------- 24.1/38.4 MB 118.1 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.4 MB 114.9 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.4 MB 114.9 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.4 MB 114.9 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.4 MB 114.9 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.4 MB 114.9 MB/s eta 0:00:01
#    ---------------------------------------- 38.4/38.4 MB 29.1 MB/s eta 0:00:00
# Installing collected packages: scipy
# Successfully installed scipy-1.16.0

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.3-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.58.4-cp313-cp313-win_amd64.whl.metadata (108 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\miranda family\new folder\envs\control-system\lib\site-packages (from matplotlib) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\miranda family\new folder\envs\control-system\lib\site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.3.0-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\miranda family\new folder\envs\control-system\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\miranda family\new folder\envs\control-system\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.3-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 8.1/8.1 MB 48.6 MB/s eta 0:00:00
# Downloading contourpy-1.3.2-cp313-cp313-win_amd64.whl (223 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.58.4-cp313-cp313-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 46.2 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp313-cp313-win_amd64.whl (71 kB)
# Downloading pillow-11.3.0-cp313-cp313-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 7.0/7.0 MB 63.9 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.58.4 kiwisolver-1.4.8 matplotlib-3.10.3 pillow-11.3.0 pyparsing-3.2.3

# %%
# !pip install panda
# Out:
# Collecting panda
#   Using cached panda-0.3.1-py3-none-any.whl
# Requirement already satisfied: setuptools in c:\users\miranda family\new folder\envs\control-system\lib\site-packages (from panda) (78.1.1)
# Requirement already satisfied: requests in c:\users\miranda family\new folder\envs\control-system\lib\site-packages (from panda) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\miranda family\new folder\envs\control-system\lib\site-packages (from requests->panda) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\miranda family\new folder\envs\control-system\lib\site-packages (from requests->panda) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\miranda family\new folder\envs\control-system\lib\site-packages (from requests->panda) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\miranda family\new folder\envs\control-system\lib\site-packages (from requests->panda) (2025.6.15)
# Installing collected packages: panda
# Successfully installed panda-0.3.1

# %%
# !pip install gekko
# Out:
# Collecting gekko
#   Using cached gekko-1.3.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.8 in c:\users\miranda family\new folder\envs\control-system\lib\site-packages (from gekko) (2.3.1)
# Using cached gekko-1.3.0-py3-none-any.whl (13.2 MB)
# Installing collected packages: gekko
# Successfully installed gekko-1.3.0

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.0-cp313-cp313-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\miranda family\new folder\envs\control-system\lib\site-packages (from scikit-learn) (2.3.1)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\miranda family\new folder\envs\control-system\lib\site-packages (from scikit-learn) (1.16.0)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.0-cp313-cp313-win_amd64.whl (10.7 MB)
#    ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#    ---------------------------------------  10.5/10.7 MB 108.0 MB/s eta 0:00:01
#    ---------------------------------------- 10.7/10.7 MB 50.1 MB/s eta 0:00:00
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
#
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    -------------------------- ------------- 2/3 [scikit-learn]
#    ---------------------------------------- 3/3 [scikit-learn]
#
# Successfully installed joblib-1.5.1 scikit-learn-1.7.0 threadpoolctl-3.6.0

# %%
# !pip install sympy
# Out:
# Collecting sympy
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------  6.3/6.3 MB 113.0 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 18.7 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 7.9 MB/s eta 0:00:00
# Installing collected packages: mpmath, sympy
#
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
#    ---------------------------------------- 0/2 [mpmath]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    -------------------- ------------------- 1/2 [sympy]
#    ---------------------------------------- 2/2 [sympy]
#
# Successfully installed mpmath-1.3.0 sympy-1.14.0

# %% [markdown]
# ### Machine Problem 002: Inverse Laplace Transforms
#
# Finding a function $f(t)$, given the Laplace transform $F(s)$.  If $L{f(t)} = F(s)$ we write:
#
# $f(t) = \mathcal{L}^{-1}\left(F(s)\right)$
#
# The SymPy library is a symbolic mathematics library written for Python that can be used to perform analytical calculations. This library can be very useful for control system design and analysis.

# %% [markdown]
# ### Table of Common Laplace Transforms
# Mathematicians have developed tables of commonly used Laplace transforms. Here is summary table with a few of the entries that will be most common for analysis of linear differential equations.
#
# | **Item no.** | **f(t)**                | **F(s)**                           |
# |--------------|-------------------------|------------------------------------|
# | 1.           | $ \delta(t) $           | $ 1 $                              |
# | 2.           | $ u(t) $                | $ \frac{1}{s} $                    |
# | 3.           | $ tu(t) $               | $ \frac{1}{s^2} $                  |
# | 4.           | $ t^n u(t) $            | $ \frac{n!}{s^{n+1}} $             |
# | 5.           | $ e^{-at}u(t) $         | $ \frac{1}{s + a} $                |
# | 6.           | $ \sin(\omega t)u(t) $  | $ \frac{\omega}{s^2 + \omega^2} $  |
# | 7.           | $ \cos(\omega t)u(t) $  | $ \frac{s}{s^2 + \omega^2} $       |

# %%
import sympy as sym
from sympy.abc import s,t,u,x,y,z,a,b,c,k
from sympy.integrals import inverse_laplace_transform

# %%
# For pretty  printing
sym.init_printing()

# %%
# Define variables for time 't' and complex variable 's'
# t = sym.symbols('t', real=True)
# s = sym.symbols('s')

# Define a constant:
# a = sym.symbols('a', real=True, positive=True)

# %% [markdown]
# 1. Evaluate:
#
# $$ \mathcal{L}^{-1}\{\frac{2}{s^3}\} = t^2 $$

# %%
# Define the frequency domain function:
f1s = 2/s**3
f1s
# Out:
# Matplotlib is building the font cache; this may take a moment.
# 2
# ──
#  3
# s

# %%
# Compute the Inverse Laplace Transform:
f1 = inverse_laplace_transform(f1s, s, t)
f1
# Out:
#  2
# t ⋅θ(t)

# %% [markdown]
# 2. Evaluate:
#
# $$ \mathcal{L}^{-1}\frac{s}{s^2+1}= cos(t) $$

# %%
# Define the frequency domain function:
f2s = s/(s**2+1)
f2s
# Out:
#   s
# ──────
#  2
# s  + 1

# %%
# Compute the Inverse Laplace Transform:
f2 = inverse_laplace_transform(f2s, s, t)
f2
# Out:
# cos(t)⋅θ(t)

# %% [markdown]
# 3. Evaluate:
# $$ \mathcal{L}^{-1}\frac{1}{s^2+1}= sin(t) $$

# %%
# Define the frequency domain function:
f3s = 1/(s**2+1)
f3s
# Out:
#   1
# ──────
#  2
# s  + 1

# %%
# Laplace transform (t->s)
f3 = inverse_laplace_transform(f3s, s, t)
f3
# Out:
# sin(t)⋅θ(t)

# %% [markdown]
# 4. Evaluate:
#
# $$ \mathcal{L}^{-1}\frac{10}{(s+2)^4}= \frac{5t^3e^{-2t}}{3} $$

# %%
# Define the frequency domain function:
f4s = 10/ (s + 2)**4
f4s
# Out:
#    10
# ────────
#        4
# (s + 2)

# %%
# Compute the Inverse Laplace Transform:
f4 = inverse_laplace_transform(f4s, s, t)
f4
# Out:
#    3  -2⋅t
# 5⋅t ⋅ℯ    ⋅θ(t)
# ───────────────
#        3

# %% [markdown]
# 5. Evaluate:
#
# $$ \mathcal{L}^{-1}\frac{s+1}{(s+1)^2+4} = e^{-t}cos2t $$

# %%
# Define the frequency domain function:
f5 = (s + 1) / ((s + 1)**2 + 4)
f5
# Out:
#    s + 1
# ────────────
#        2
# (s + 1)  + 4

# %%
# Compute the Inverse Laplace Transform:
f5 = inverse_laplace_transform(f5, s, t)
f5
# Out:
#  -t
# ℯ  ⋅cos(2⋅t)⋅θ(t)

# %% [markdown]
# 6. Evaluate:
#
# $$ \mathcal{L}^{-1}\frac{15}{(s-1)^2-9} = 5e^{t}sinh3t $$

# %%
# Define the frequency domain function:
f6 = 15 / ((s - 1)**2 - 9)
f6
# Out:
#      15
# ────────────
#        2
# (s - 1)  - 9

# %%
# Compute the Inverse Laplace Transform:
f6 = inverse_laplace_transform(f6, s, t)
f6
# Out:
#    4⋅t           -2⋅t
# 5⋅ℯ   ⋅θ(t)   5⋅ℯ    ⋅θ(t)
# ─────────── - ────────────
#      2             2

# %% [markdown]
# 7. Evaluate:
#
# $$ \mathcal{L}^{-1}\frac{4s-1}{s^2-s}= 1 + 3e^t $$

# %%
# Define the frequency domain function:
f7= (4*s - 1) / (s**2 - s)
f7
# Out:
# 4⋅s - 1
# ───────
#  2
# s  - s

# %%
# Compute the Inverse Laplace Transform:
f7 = inverse_laplace_transform(f7, s, t)
f7
# Out:
#    t
# 3⋅ℯ ⋅θ(t) + θ(t)
